# %% [markdown]
# **IMPORT FOLLOWING LIBRARIES**

# %%
#PREDICTION OF SINGLE IMAGE
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt                                         
import cv2

# %% [markdown]
# # TEST FOR COVID-19

# %%
# Load the trained model
model = keras.models.load_model('C:/Users/Rithanya/Desktop/covid check')

# %% [markdown]
# # TEST FOR PNEUMONIA

# %%
# Load the trained model
model = keras.models.load_model('C:/Users/Rithanya/Desktop/modelxrays')

# %% [markdown]
# # TEST FOR TUBERCULOSIS (TB)

# %%
# Load the trained model
model = keras.models.load_model('C:/Users/Rithanya/Desktop/TB check')

# %% [markdown]
# **LOAD XRAY IMAGE OF PATIENT**

# %%
# Load a single test image
img_path = "C:/Users/Rithanya/Desktop/Test images/pat1.jpeg"
img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img = cv2.resize(img, (224, 224))

# %%
# Preprocess the image
img = img / 255.0
img = np.expand_dims(img, axis=0)

# %%
# Predict the class probabilities
probs = model.predict(img)
# Out:
# 1/1 [==============================] - 0s 172ms/step

# %%
# Visualize the image and the predicted probabilities
plt.imshow(img[0])
plt.title(f'COVID Probability: {probs[0][0]:.2f}')
plt.axis('off')
plt.show()
